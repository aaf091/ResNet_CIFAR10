# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

deep_learning_spring_2025_project_1_path = kagglehub.competition_download('deep-learning-spring-2025-project-1')

print('Data source import complete.')
# Out:
# Downloading from https://www.kaggle.com/api/v1/competitions/data/download-all/deep-learning-spring-2025-project-1...
# 100%|██████████| 189M/189M [00:00<00:00, 217MB/s]
# Extracting files...
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Custom ResNet for CIFAR-10 on CUDA
#
# This notebook implements a custom ResNet model for CIFAR-10 using PyTorch. It includes two major sections:
#
# 1. **Training Section:** Loads the CIFAR-10 training and test sets via torchvision, trains the model, and saves a checkpoint.
#
# 2. **Inference Section:** Loads a test batch from a pickle file (with no labels), runs inference using the trained model (if available), and saves the predictions to a CSV file.
#
# Make sure the test pickle file is located at `/kaggle/input/deep-learning-spring-2025-project-1/cifar_test_nolabel.pkl` for inference.

# %%
import os
import pickle
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import torchvision
import torchvision.transforms as transforms
import pandas as pd

from PIL import Image

# %%
# Model Definitions

class BasicBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )
        else:
            self.shortcut = nn.Identity()

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = self.relu(out)
        return out


class CustomResNet(nn.Module):
    def __init__(self, blocks_per_stage=[3, 4, 4, 3], base_channels=32, num_classes=10):
        """
        Args:
            blocks_per_stage (list): Four integers specifying the number of residual blocks per stage.
            base_channels (int): Number of channels for the initial convolution.
            num_classes (int): Number of output classes.
        """
        super(CustomResNet, self).__init__()
        self.in_channels = base_channels
        # Initial convolution for CIFAR-10 (3-channel, 32x32 images)
        self.conv1 = nn.Conv2d(3, base_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(base_channels)
        self.relu = nn.ReLU(inplace=True)

        self.layer1 = self._make_layer(base_channels, blocks_per_stage[0], stride=1)
        self.layer2 = self._make_layer(base_channels * 2, blocks_per_stage[1], stride=2)
        self.layer3 = self._make_layer(base_channels * 4, blocks_per_stage[2], stride=2)
        self.layer4 = self._make_layer(base_channels * 8, blocks_per_stage[3], stride=2)

        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(base_channels * 8, num_classes)

    def _make_layer(self, out_channels, num_blocks, stride):
        layers = []
        layers.append(BasicBlock(self.in_channels, out_channels, stride))
        self.in_channels = out_channels
        for _ in range(1, num_blocks):
            layers.append(BasicBlock(out_channels, out_channels, stride=1))
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.avg_pool(out)
        out = torch.flatten(out, 1)
        out = self.fc(out)
        return out

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
# Data Loading Function for CIFAR-10 using torchvision
def get_data(batch_size=128):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

    train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
    test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)
    return train_loader, test_loader

# %%
# Training and Testing Functions
def train(model, train_loader, optimizer, criterion, device, epoch, print_interval=50):
    model.train()
    running_loss = 0.0
    for i, (inputs, targets) in enumerate(train_loader, 1):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        if i % print_interval == 0:
            print(f"Epoch: {epoch} | Iteration: {i} | Loss: {running_loss / print_interval:.3f}")
            running_loss = 0.0

def test(model, test_loader, device, epoch):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
    accuracy = correct / total
    print(f"Epoch {epoch}: Test accuracy: {accuracy:.3f}")
    return accuracy

# %%
# Set device: Use Apple MPS if available, otherwise CUDA or CPU
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print("Using device:", device)

# Instantiate the model and print the parameter count
model = CustomResNet(blocks_per_stage=[3, 4, 4, 3], base_channels=32, num_classes=10).to(device)
print("Total parameters:", count_parameters(model))
# Out:
# Using device: cuda
# Total parameters: 4735658

# %%
# Training Mode
# This cell trains the model on CIFAR-10 and saves a checkpoint.

train_loader, test_loader = get_data(batch_size=128)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()
epochs = 60  # Adjust epochs as needed

for epoch in range(1, epochs + 1):
    train(model, train_loader, optimizer, criterion, device, epoch)
    test(model, test_loader, device, epoch)

# Save the trained model checkpoint
torch.save(model.state_dict(), "model_checkpoint.pth")
print("Model checkpoint saved to model_checkpoint.pth")
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:03<00:00, 43.8MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Epoch: 1 | Iteration: 50 | Loss: 1.971
# Epoch: 1 | Iteration: 100 | Loss: 1.688
# Epoch: 1 | Iteration: 150 | Loss: 1.566
# Epoch: 1 | Iteration: 200 | Loss: 1.478
# Epoch: 1 | Iteration: 250 | Loss: 1.395
# Epoch: 1 | Iteration: 300 | Loss: 1.321
# Epoch: 1 | Iteration: 350 | Loss: 1.245
# Epoch 1: Test accuracy: 0.499
# Epoch: 2 | Iteration: 50 | Loss: 1.160
# Epoch: 2 | Iteration: 100 | Loss: 1.116
# Epoch: 2 | Iteration: 150 | Loss: 1.076
# Epoch: 2 | Iteration: 200 | Loss: 1.036
# Epoch: 2 | Iteration: 250 | Loss: 0.993
# Epoch: 2 | Iteration: 300 | Loss: 0.939
# Epoch: 2 | Iteration: 350 | Loss: 0.962
# Epoch 2: Test accuracy: 0.680
# Epoch: 3 | Iteration: 50 | Loss: 0.861
# Epoch: 3 | Iteration: 100 | Loss: 0.860
# Epoch: 3 | Iteration: 150 | Loss: 0.787
# Epoch: 3 | Iteration: 200 | Loss: 0.810
# Epoch: 3 | Iteration: 250 | Loss: 0.776
# Epoch: 3 | Iteration: 300 | Loss: 0.737
# Epoch: 3 | Iteration: 350 | Loss: 0.752
# Epoch 3: Test accuracy: 0.712
# Epoch: 4 | Iteration: 50 | Loss: 0.687
# Epoch: 4 | Iteration: 100 | Loss: 0.685
# Epoch: 4 | Iteration: 150 | Loss: 0.703
# Epoch: 4 | Iteration: 200 | Loss: 0.690
# Epoch: 4 | Iteration: 250 | Loss: 0.655
# Epoch: 4 | Iteration: 300 | Loss: 0.644
# Epoch: 4 | Iteration: 350 | Loss: 0.629
# Epoch 4: Test accuracy: 0.770
# Epoch: 5 | Iteration: 50 | Loss: 0.598
# Epoch: 5 | Iteration: 100 | Loss: 0.561
# Epoch: 5 | Iteration: 150 | Loss: 0.589
# Epoch: 5 | Iteration: 200 | Loss: 0.592
# Epoch: 5 | Iteration: 250 | Loss: 0.568
# Epoch: 5 | Iteration: 300 | Loss: 0.569
# Epoch: 5 | Iteration: 350 | Loss: 0.545
# Epoch 5: Test accuracy: 0.755
# Epoch: 6 | Iteration: 50 | Loss: 0.516
# Epoch: 6 | Iteration: 100 | Loss: 0.547
# Epoch: 6 | Iteration: 150 | Loss: 0.515
# Epoch: 6 | Iteration: 200 | Loss: 0.499
# Epoch: 6 | Iteration: 250 | Loss: 0.519
# Epoch: 6 | Iteration: 300 | Loss: 0.501
# Epoch: 6 | Iteration: 350 | Loss: 0.508
# Epoch 6: Test accuracy: 0.813
# Epoch: 7 | Iteration: 50 | Loss: 0.465
# Epoch: 7 | Iteration: 100 | Loss: 0.461
# Epoch: 7 | Iteration: 150 | Loss: 0.496
# Epoch: 7 | Iteration: 200 | Loss: 0.473
# Epoch: 7 | Iteration: 250 | Loss: 0.473
# Epoch: 7 | Iteration: 300 | Loss: 0.478
# Epoch: 7 | Iteration: 350 | Loss: 0.457
# Epoch 7: Test accuracy: 0.813
# Epoch: 8 | Iteration: 50 | Loss: 0.428
# Epoch: 8 | Iteration: 100 | Loss: 0.428
# Epoch: 8 | Iteration: 150 | Loss: 0.448
# Epoch: 8 | Iteration: 200 | Loss: 0.425
# Epoch: 8 | Iteration: 250 | Loss: 0.440
# Epoch: 8 | Iteration: 300 | Loss: 0.433
# Epoch: 8 | Iteration: 350 | Loss: 0.422
# Epoch 8: Test accuracy: 0.820
# Epoch: 9 | Iteration: 50 | Loss: 0.406
# Epoch: 9 | Iteration: 100 | Loss: 0.391
# Epoch: 9 | Iteration: 150 | Loss: 0.389
# Epoch: 9 | Iteration: 200 | Loss: 0.409
# Epoch: 9 | Iteration: 250 | Loss: 0.409
# Epoch: 9 | Iteration: 300 | Loss: 0.401
# Epoch: 9 | Iteration: 350 | Loss: 0.399
# Epoch 9: Test accuracy: 0.827
# Epoch: 10 | Iteration: 50 | Loss: 0.373
# Epoch: 10 | Iteration: 100 | Loss: 0.381
# Epoch: 10 | Iteration: 150 | Loss: 0.388
# Epoch: 10 | Iteration: 200 | Loss: 0.366
# Epoch: 10 | Iteration: 250 | Loss: 0.387
# Epoch: 10 | Iteration: 300 | Loss: 0.378
# Epoch: 10 | Iteration: 350 | Loss: 0.383
# Epoch 10: Test accuracy: 0.845
# Epoch: 11 | Iteration: 50 | Loss: 0.352
# Epoch: 11 | Iteration: 100 | Loss: 0.339
# Epoch: 11 | Iteration: 150 | Loss: 0.334
# Epoch: 11 | Iteration: 200 | Loss: 0.375
# Epoch: 11 | Iteration: 250 | Loss: 0.313
# Epoch: 11 | Iteration: 300 | Loss: 0.350
# Epoch: 11 | Iteration: 350 | Loss: 0.345
# Epoch 11: Test accuracy: 0.824
# Epoch: 12 | Iteration: 50 | Loss: 0.307
# Epoch: 12 | Iteration: 100 | Loss: 0.330
# Epoch: 12 | Iteration: 150 | Loss: 0.324
# Epoch: 12 | Iteration: 200 | Loss: 0.337
# Epoch: 12 | Iteration: 250 | Loss: 0.316
# Epoch: 12 | Iteration: 300 | Loss: 0.327
# Epoch: 12 | Iteration: 350 | Loss: 0.320
# Epoch 12: Test accuracy: 0.855
# Epoch: 13 | Iteration: 50 | Loss: 0.285
# Epoch: 13 | Iteration: 100 | Loss: 0.306
# Epoch: 13 | Iteration: 150 | Loss: 0.316
# Epoch: 13 | Iteration: 200 | Loss: 0.319
# Epoch: 13 | Iteration: 250 | Loss: 0.327
# Epoch: 13 | Iteration: 300 | Loss: 0.318
# Epoch: 13 | Iteration: 350 | Loss: 0.283
# Epoch 13: Test accuracy: 0.857
# Epoch: 14 | Iteration: 50 | Loss: 0.283
# Epoch: 14 | Iteration: 100 | Loss: 0.291
# Epoch: 14 | Iteration: 150 | Loss: 0.268
# Epoch: 14 | Iteration: 200 | Loss: 0.267
# Epoch: 14 | Iteration: 250 | Loss: 0.293
# Epoch: 14 | Iteration: 300 | Loss: 0.285
# Epoch: 14 | Iteration: 350 | Loss: 0.310
# Epoch 14: Test accuracy: 0.867
# Epoch: 15 | Iteration: 50 | Loss: 0.249
# Epoch: 15 | Iteration: 100 | Loss: 0.254
# Epoch: 15 | Iteration: 150 | Loss: 0.281
# Epoch: 15 | Iteration: 200 | Loss: 0.290
# Epoch: 15 | Iteration: 250 | Loss: 0.285
# Epoch: 15 | Iteration: 300 | Loss: 0.267
# Epoch: 15 | Iteration: 350 | Loss: 0.290
# Epoch 15: Test accuracy: 0.876
# Epoch: 16 | Iteration: 50 | Loss: 0.237
# Epoch: 16 | Iteration: 100 | Loss: 0.250
# Epoch: 16 | Iteration: 150 | Loss: 0.253
# Epoch: 16 | Iteration: 200 | Loss: 0.259
# Epoch: 16 | Iteration: 250 | Loss: 0.262
# Epoch: 16 | Iteration: 300 | Loss: 0.265
# Epoch: 16 | Iteration: 350 | Loss: 0.251
# Epoch 16: Test accuracy: 0.854
# Epoch: 17 | Iteration: 50 | Loss: 0.226
# Epoch: 17 | Iteration: 100 | Loss: 0.237
# Epoch: 17 | Iteration: 150 | Loss: 0.253
# Epoch: 17 | Iteration: 200 | Loss: 0.227
# Epoch: 17 | Iteration: 250 | Loss: 0.248
# Epoch: 17 | Iteration: 300 | Loss: 0.258
# Epoch: 17 | Iteration: 350 | Loss: 0.251
# Epoch 17: Test accuracy: 0.881
# Epoch: 18 | Iteration: 50 | Loss: 0.223
# Epoch: 18 | Iteration: 100 | Loss: 0.219
# Epoch: 18 | Iteration: 150 | Loss: 0.226
# Epoch: 18 | Iteration: 200 | Loss: 0.228
# Epoch: 18 | Iteration: 250 | Loss: 0.225
# Epoch: 18 | Iteration: 300 | Loss: 0.258
# Epoch: 18 | Iteration: 350 | Loss: 0.245
# Epoch 18: Test accuracy: 0.880
# Epoch: 19 | Iteration: 50 | Loss: 0.217
# Epoch: 19 | Iteration: 100 | Loss: 0.210
# Epoch: 19 | Iteration: 150 | Loss: 0.218
# Epoch: 19 | Iteration: 200 | Loss: 0.229
# Epoch: 19 | Iteration: 250 | Loss: 0.219
# Epoch: 19 | Iteration: 300 | Loss: 0.197
# Epoch: 19 | Iteration: 350 | Loss: 0.224
# Epoch 19: Test accuracy: 0.890
# Epoch: 20 | Iteration: 50 | Loss: 0.200
# Epoch: 20 | Iteration: 100 | Loss: 0.206
# Epoch: 20 | Iteration: 150 | Loss: 0.193
# Epoch: 20 | Iteration: 200 | Loss: 0.195
# Epoch: 20 | Iteration: 250 | Loss: 0.232
# Epoch: 20 | Iteration: 300 | Loss: 0.205
# Epoch: 20 | Iteration: 350 | Loss: 0.214
# Epoch 20: Test accuracy: 0.881
# Epoch: 21 | Iteration: 50 | Loss: 0.195
# Epoch: 21 | Iteration: 100 | Loss: 0.208
# Epoch: 21 | Iteration: 150 | Loss: 0.180
# Epoch: 21 | Iteration: 200 | Loss: 0.194
# Epoch: 21 | Iteration: 250 | Loss: 0.187
# Epoch: 21 | Iteration: 300 | Loss: 0.192
# Epoch: 21 | Iteration: 350 | Loss: 0.199
# Epoch 21: Test accuracy: 0.871
# Epoch: 22 | Iteration: 50 | Loss: 0.156
# Epoch: 22 | Iteration: 100 | Loss: 0.173
# Epoch: 22 | Iteration: 150 | Loss: 0.187
# Epoch: 22 | Iteration: 200 | Loss: 0.198
# Epoch: 22 | Iteration: 250 | Loss: 0.172
# Epoch: 22 | Iteration: 300 | Loss: 0.198
# Epoch: 22 | Iteration: 350 | Loss: 0.188
# Epoch 22: Test accuracy: 0.888
# Epoch: 23 | Iteration: 50 | Loss: 0.167
# Epoch: 23 | Iteration: 100 | Loss: 0.166
# Epoch: 23 | Iteration: 150 | Loss: 0.170
# Epoch: 23 | Iteration: 200 | Loss: 0.165
# Epoch: 23 | Iteration: 250 | Loss: 0.179
# Epoch: 23 | Iteration: 300 | Loss: 0.174
# Epoch: 23 | Iteration: 350 | Loss: 0.187
# Epoch 23: Test accuracy: 0.890
# Epoch: 24 | Iteration: 50 | Loss: 0.155
# Epoch: 24 | Iteration: 100 | Loss: 0.157
# Epoch: 24 | Iteration: 150 | Loss: 0.159
# Epoch: 24 | Iteration: 200 | Loss: 0.180
# Epoch: 24 | Iteration: 250 | Loss: 0.168
# Epoch: 24 | Iteration: 300 | Loss: 0.185
# Epoch: 24 | Iteration: 350 | Loss: 0.174
# Epoch 24: Test accuracy: 0.892
# Epoch: 25 | Iteration: 50 | Loss: 0.134
# Epoch: 25 | Iteration: 100 | Loss: 0.143
# Epoch: 25 | Iteration: 150 | Loss: 0.164
# Epoch: 25 | Iteration: 200 | Loss: 0.177
# Epoch: 25 | Iteration: 250 | Loss: 0.173
# Epoch: 25 | Iteration: 300 | Loss: 0.153
# Epoch: 25 | Iteration: 350 | Loss: 0.164
# Epoch 25: Test accuracy: 0.882
# Epoch: 26 | Iteration: 50 | Loss: 0.147
# Epoch: 26 | Iteration: 100 | Loss: 0.146
# Epoch: 26 | Iteration: 150 | Loss: 0.162
# Epoch: 26 | Iteration: 200 | Loss: 0.151
# Epoch: 26 | Iteration: 250 | Loss: 0.148
# Epoch: 26 | Iteration: 300 | Loss: 0.153
# Epoch: 26 | Iteration: 350 | Loss: 0.152
# Epoch 26: Test accuracy: 0.893
# Epoch: 27 | Iteration: 50 | Loss: 0.139
# Epoch: 27 | Iteration: 100 | Loss: 0.132
# Epoch: 27 | Iteration: 150 | Loss: 0.140
# Epoch: 27 | Iteration: 200 | Loss: 0.132
# Epoch: 27 | Iteration: 250 | Loss: 0.134
# Epoch: 27 | Iteration: 300 | Loss: 0.139
# Epoch: 27 | Iteration: 350 | Loss: 0.160
# Epoch 27: Test accuracy: 0.893
# Epoch: 28 | Iteration: 50 | Loss: 0.127
# Epoch: 28 | Iteration: 100 | Loss: 0.123
# Epoch: 28 | Iteration: 150 | Loss: 0.125
# Epoch: 28 | Iteration: 200 | Loss: 0.141
# Epoch: 28 | Iteration: 250 | Loss: 0.136
# Epoch: 28 | Iteration: 300 | Loss: 0.150
# Epoch: 28 | Iteration: 350 | Loss: 0.139
# Epoch 28: Test accuracy: 0.901
# Epoch: 29 | Iteration: 50 | Loss: 0.127
# Epoch: 29 | Iteration: 100 | Loss: 0.125
# Epoch: 29 | Iteration: 150 | Loss: 0.139
# Epoch: 29 | Iteration: 200 | Loss: 0.134
# Epoch: 29 | Iteration: 250 | Loss: 0.120
# Epoch: 29 | Iteration: 300 | Loss: 0.137
# Epoch: 29 | Iteration: 350 | Loss: 0.136
# Epoch 29: Test accuracy: 0.895
# Epoch: 30 | Iteration: 50 | Loss: 0.133
# Epoch: 30 | Iteration: 100 | Loss: 0.115
# Epoch: 30 | Iteration: 150 | Loss: 0.124
# Epoch: 30 | Iteration: 200 | Loss: 0.124
# Epoch: 30 | Iteration: 250 | Loss: 0.123
# Epoch: 30 | Iteration: 300 | Loss: 0.120
# Epoch: 30 | Iteration: 350 | Loss: 0.139
# Epoch 30: Test accuracy: 0.898
# Epoch: 31 | Iteration: 50 | Loss: 0.099
# Epoch: 31 | Iteration: 100 | Loss: 0.115
# Epoch: 31 | Iteration: 150 | Loss: 0.109
# Epoch: 31 | Iteration: 200 | Loss: 0.110
# Epoch: 31 | Iteration: 250 | Loss: 0.111
# Epoch: 31 | Iteration: 300 | Loss: 0.127
# Epoch: 31 | Iteration: 350 | Loss: 0.141
# Epoch 31: Test accuracy: 0.898
# Epoch: 32 | Iteration: 50 | Loss: 0.102
# Epoch: 32 | Iteration: 100 | Loss: 0.092
# Epoch: 32 | Iteration: 150 | Loss: 0.113
# Epoch: 32 | Iteration: 200 | Loss: 0.120
# Epoch: 32 | Iteration: 250 | Loss: 0.124
# Epoch: 32 | Iteration: 300 | Loss: 0.122
# Epoch: 32 | Iteration: 350 | Loss: 0.111
# Epoch 32: Test accuracy: 0.903
# Epoch: 33 | Iteration: 50 | Loss: 0.104
# Epoch: 33 | Iteration: 100 | Loss: 0.113
# Epoch: 33 | Iteration: 150 | Loss: 0.115
# Epoch: 33 | Iteration: 200 | Loss: 0.111
# Epoch: 33 | Iteration: 250 | Loss: 0.110
# Epoch: 33 | Iteration: 300 | Loss: 0.102
# Epoch: 33 | Iteration: 350 | Loss: 0.114
# Epoch 33: Test accuracy: 0.900
# Epoch: 34 | Iteration: 50 | Loss: 0.096
# Epoch: 34 | Iteration: 100 | Loss: 0.104
# Epoch: 34 | Iteration: 150 | Loss: 0.091
# Epoch: 34 | Iteration: 200 | Loss: 0.112
# Epoch: 34 | Iteration: 250 | Loss: 0.105
# Epoch: 34 | Iteration: 300 | Loss: 0.104
# Epoch: 34 | Iteration: 350 | Loss: 0.100
# Epoch 34: Test accuracy: 0.892
# Epoch: 35 | Iteration: 50 | Loss: 0.097
# Epoch: 35 | Iteration: 100 | Loss: 0.084
# Epoch: 35 | Iteration: 150 | Loss: 0.080
# Epoch: 35 | Iteration: 200 | Loss: 0.099
# Epoch: 35 | Iteration: 250 | Loss: 0.108
# Epoch: 35 | Iteration: 300 | Loss: 0.108
# Epoch: 35 | Iteration: 350 | Loss: 0.103
# Epoch 35: Test accuracy: 0.902
# Epoch: 36 | Iteration: 50 | Loss: 0.069
# Epoch: 36 | Iteration: 100 | Loss: 0.095
# Epoch: 36 | Iteration: 150 | Loss: 0.104
# Epoch: 36 | Iteration: 200 | Loss: 0.103
# Epoch: 36 | Iteration: 250 | Loss: 0.105
# Epoch: 36 | Iteration: 300 | Loss: 0.090
# Epoch: 36 | Iteration: 350 | Loss: 0.100
# Epoch 36: Test accuracy: 0.902
# Epoch: 37 | Iteration: 50 | Loss: 0.086
# Epoch: 37 | Iteration: 100 | Loss: 0.079
# Epoch: 37 | Iteration: 150 | Loss: 0.092
# Epoch: 37 | Iteration: 200 | Loss: 0.090
# Epoch: 37 | Iteration: 250 | Loss: 0.086
# Epoch: 37 | Iteration: 300 | Loss: 0.083
# Epoch: 37 | Iteration: 350 | Loss: 0.095
# Epoch 37: Test accuracy: 0.893
# Epoch: 38 | Iteration: 50 | Loss: 0.109
# Epoch: 38 | Iteration: 100 | Loss: 0.094
# Epoch: 38 | Iteration: 150 | Loss: 0.088
# Epoch: 38 | Iteration: 200 | Loss: 0.083
# Epoch: 38 | Iteration: 250 | Loss: 0.084
# Epoch: 38 | Iteration: 300 | Loss: 0.101
# Epoch: 38 | Iteration: 350 | Loss: 0.102
# Epoch 38: Test accuracy: 0.902
# Epoch: 39 | Iteration: 50 | Loss: 0.078
# Epoch: 39 | Iteration: 100 | Loss: 0.078
# Epoch: 39 | Iteration: 150 | Loss: 0.073
# Epoch: 39 | Iteration: 200 | Loss: 0.096
# Epoch: 39 | Iteration: 250 | Loss: 0.091
# Epoch: 39 | Iteration: 300 | Loss: 0.092
# Epoch: 39 | Iteration: 350 | Loss: 0.083
# Epoch 39: Test accuracy: 0.904
# Epoch: 40 | Iteration: 50 | Loss: 0.075
# Epoch: 40 | Iteration: 100 | Loss: 0.085
# Epoch: 40 | Iteration: 150 | Loss: 0.086
# Epoch: 40 | Iteration: 200 | Loss: 0.100
# Epoch: 40 | Iteration: 250 | Loss: 0.091
# Epoch: 40 | Iteration: 300 | Loss: 0.073
# Epoch: 40 | Iteration: 350 | Loss: 0.078
# Epoch 40: Test accuracy: 0.901
# Epoch: 41 | Iteration: 50 | Loss: 0.064
# Epoch: 41 | Iteration: 100 | Loss: 0.064
# Epoch: 41 | Iteration: 150 | Loss: 0.074
# Epoch: 41 | Iteration: 200 | Loss: 0.077
# Epoch: 41 | Iteration: 250 | Loss: 0.080
# Epoch: 41 | Iteration: 300 | Loss: 0.066
# Epoch: 41 | Iteration: 350 | Loss: 0.079
# Epoch 41: Test accuracy: 0.905
# Epoch: 42 | Iteration: 50 | Loss: 0.068
# Epoch: 42 | Iteration: 100 | Loss: 0.086
# Epoch: 42 | Iteration: 150 | Loss: 0.073
# Epoch: 42 | Iteration: 200 | Loss: 0.076
# Epoch: 42 | Iteration: 250 | Loss: 0.073
# Epoch: 42 | Iteration: 300 | Loss: 0.083
# Epoch: 42 | Iteration: 350 | Loss: 0.076
# Epoch 42: Test accuracy: 0.901
# Epoch: 43 | Iteration: 50 | Loss: 0.069
# Epoch: 43 | Iteration: 100 | Loss: 0.060
# Epoch: 43 | Iteration: 150 | Loss: 0.069
# Epoch: 43 | Iteration: 200 | Loss: 0.061
# Epoch: 43 | Iteration: 250 | Loss: 0.071
# Epoch: 43 | Iteration: 300 | Loss: 0.075
# Epoch: 43 | Iteration: 350 | Loss: 0.077
# Epoch 43: Test accuracy: 0.913
# Epoch: 44 | Iteration: 50 | Loss: 0.058
# Epoch: 44 | Iteration: 100 | Loss: 0.066
# Epoch: 44 | Iteration: 150 | Loss: 0.071
# Epoch: 44 | Iteration: 200 | Loss: 0.074
# Epoch: 44 | Iteration: 250 | Loss: 0.069
# Epoch: 44 | Iteration: 300 | Loss: 0.076
# Epoch: 44 | Iteration: 350 | Loss: 0.082
# Epoch 44: Test accuracy: 0.906
# Epoch: 45 | Iteration: 50 | Loss: 0.084
# Epoch: 45 | Iteration: 100 | Loss: 0.062
# Epoch: 45 | Iteration: 150 | Loss: 0.061
# Epoch: 45 | Iteration: 200 | Loss: 0.061
# Epoch: 45 | Iteration: 250 | Loss: 0.075
# Epoch: 45 | Iteration: 300 | Loss: 0.075
# Epoch: 45 | Iteration: 350 | Loss: 0.086
# Epoch 45: Test accuracy: 0.911
# Epoch: 46 | Iteration: 50 | Loss: 0.062
# Epoch: 46 | Iteration: 100 | Loss: 0.060
# Epoch: 46 | Iteration: 150 | Loss: 0.066
# Epoch: 46 | Iteration: 200 | Loss: 0.070
# Epoch: 46 | Iteration: 250 | Loss: 0.067
# Epoch: 46 | Iteration: 300 | Loss: 0.074
# Epoch: 46 | Iteration: 350 | Loss: 0.069
# Epoch 46: Test accuracy: 0.907
# Epoch: 47 | Iteration: 50 | Loss: 0.057
# Epoch: 47 | Iteration: 100 | Loss: 0.062
# Epoch: 47 | Iteration: 150 | Loss: 0.058
# Epoch: 47 | Iteration: 200 | Loss: 0.057
# Epoch: 47 | Iteration: 250 | Loss: 0.058
# Epoch: 47 | Iteration: 300 | Loss: 0.072
# Epoch: 47 | Iteration: 350 | Loss: 0.063
# Epoch 47: Test accuracy: 0.910
# Epoch: 48 | Iteration: 50 | Loss: 0.062
# Epoch: 48 | Iteration: 100 | Loss: 0.056
# Epoch: 48 | Iteration: 150 | Loss: 0.068
# Epoch: 48 | Iteration: 200 | Loss: 0.061
# Epoch: 48 | Iteration: 250 | Loss: 0.066
# Epoch: 48 | Iteration: 300 | Loss: 0.058
# Epoch: 48 | Iteration: 350 | Loss: 0.064
# Epoch 48: Test accuracy: 0.906
# Epoch: 49 | Iteration: 50 | Loss: 0.064
# Epoch: 49 | Iteration: 100 | Loss: 0.065
# Epoch: 49 | Iteration: 150 | Loss: 0.057
# Epoch: 49 | Iteration: 200 | Loss: 0.065
# Epoch: 49 | Iteration: 250 | Loss: 0.062
# Epoch: 49 | Iteration: 300 | Loss: 0.051
# Epoch: 49 | Iteration: 350 | Loss: 0.072
# Epoch 49: Test accuracy: 0.907
# Epoch: 50 | Iteration: 50 | Loss: 0.057
# Epoch: 50 | Iteration: 100 | Loss: 0.057
# Epoch: 50 | Iteration: 150 | Loss: 0.060
# Epoch: 50 | Iteration: 200 | Loss: 0.051
# Epoch: 50 | Iteration: 250 | Loss: 0.062
# Epoch: 50 | Iteration: 300 | Loss: 0.066
# Epoch: 50 | Iteration: 350 | Loss: 0.071
# Epoch 50: Test accuracy: 0.906
# Epoch: 51 | Iteration: 50 | Loss: 0.052
# Epoch: 51 | Iteration: 100 | Loss: 0.049
# Epoch: 51 | Iteration: 150 | Loss: 0.065
# Epoch: 51 | Iteration: 200 | Loss: 0.066
# Epoch: 51 | Iteration: 250 | Loss: 0.059
# Epoch: 51 | Iteration: 300 | Loss: 0.066
# Epoch: 51 | Iteration: 350 | Loss: 0.053
# Epoch 51: Test accuracy: 0.906
# Epoch: 52 | Iteration: 50 | Loss: 0.045
# Epoch: 52 | Iteration: 100 | Loss: 0.051
# Epoch: 52 | Iteration: 150 | Loss: 0.043
# Epoch: 52 | Iteration: 200 | Loss: 0.052
# Epoch: 52 | Iteration: 250 | Loss: 0.052
# Epoch: 52 | Iteration: 300 | Loss: 0.054
# Epoch: 52 | Iteration: 350 | Loss: 0.055
# Epoch 52: Test accuracy: 0.908
# Epoch: 53 | Iteration: 50 | Loss: 0.054
# Epoch: 53 | Iteration: 100 | Loss: 0.055
# Epoch: 53 | Iteration: 150 | Loss: 0.049
# Epoch: 53 | Iteration: 200 | Loss: 0.062
# Epoch: 53 | Iteration: 250 | Loss: 0.054
# Epoch: 53 | Iteration: 300 | Loss: 0.060
# Epoch: 53 | Iteration: 350 | Loss: 0.051
# Epoch 53: Test accuracy: 0.905
# Epoch: 54 | Iteration: 50 | Loss: 0.053
# Epoch: 54 | Iteration: 100 | Loss: 0.048
# Epoch: 54 | Iteration: 150 | Loss: 0.054
# Epoch: 54 | Iteration: 200 | Loss: 0.055
# Epoch: 54 | Iteration: 250 | Loss: 0.055
# Epoch: 54 | Iteration: 300 | Loss: 0.054
# Epoch: 54 | Iteration: 350 | Loss: 0.045
# Epoch 54: Test accuracy: 0.909
# Epoch: 55 | Iteration: 50 | Loss: 0.053
# Epoch: 55 | Iteration: 100 | Loss: 0.049
# Epoch: 55 | Iteration: 150 | Loss: 0.046
# Epoch: 55 | Iteration: 200 | Loss: 0.050
# Epoch: 55 | Iteration: 250 | Loss: 0.055
# Epoch: 55 | Iteration: 300 | Loss: 0.050
# Epoch: 55 | Iteration: 350 | Loss: 0.058
# Epoch 55: Test accuracy: 0.908
# Epoch: 56 | Iteration: 50 | Loss: 0.050
# Epoch: 56 | Iteration: 100 | Loss: 0.047
# Epoch: 56 | Iteration: 150 | Loss: 0.051
# Epoch: 56 | Iteration: 200 | Loss: 0.053
# Epoch: 56 | Iteration: 250 | Loss: 0.052
# Epoch: 56 | Iteration: 300 | Loss: 0.049
# Epoch: 56 | Iteration: 350 | Loss: 0.054
# Epoch 56: Test accuracy: 0.916
# Epoch: 57 | Iteration: 50 | Loss: 0.036
# Epoch: 57 | Iteration: 100 | Loss: 0.043
# Epoch: 57 | Iteration: 150 | Loss: 0.044
# Epoch: 57 | Iteration: 200 | Loss: 0.049
# Epoch: 57 | Iteration: 250 | Loss: 0.046
# Epoch: 57 | Iteration: 300 | Loss: 0.053
# Epoch: 57 | Iteration: 350 | Loss: 0.055
# Epoch 57: Test accuracy: 0.912
# Epoch: 58 | Iteration: 50 | Loss: 0.043
# Epoch: 58 | Iteration: 100 | Loss: 0.052
# Epoch: 58 | Iteration: 150 | Loss: 0.051
# Epoch: 58 | Iteration: 200 | Loss: 0.044
# Epoch: 58 | Iteration: 250 | Loss: 0.037
# Epoch: 58 | Iteration: 300 | Loss: 0.042
# Epoch: 58 | Iteration: 350 | Loss: 0.042
# Epoch 58: Test accuracy: 0.910
# Epoch: 59 | Iteration: 50 | Loss: 0.036
# Epoch: 59 | Iteration: 100 | Loss: 0.037
# Epoch: 59 | Iteration: 150 | Loss: 0.048
# Epoch: 59 | Iteration: 200 | Loss: 0.053
# Epoch: 59 | Iteration: 250 | Loss: 0.042
# Epoch: 59 | Iteration: 300 | Loss: 0.049
# Epoch: 59 | Iteration: 350 | Loss: 0.049
# Epoch 59: Test accuracy: 0.904
# Epoch: 60 | Iteration: 50 | Loss: 0.042
# Epoch: 60 | Iteration: 100 | Loss: 0.048
# Epoch: 60 | Iteration: 150 | Loss: 0.036
# Epoch: 60 | Iteration: 200 | Loss: 0.043
# Epoch: 60 | Iteration: 250 | Loss: 0.053
# Epoch: 60 | Iteration: 300 | Loss: 0.059
# Epoch: 60 | Iteration: 350 | Loss: 0.045
# Epoch 60: Test accuracy: 0.912
# Model checkpoint saved to model_checkpoint.pth

# %%
# Template code for reading the test file
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Load the test batch (update the file path if necessary)
cifar10_batch = load_cifar_batch('/content/cifar_test_nolabel.pkl')

# Extract images; the test data is in (N x W x H x C) format
images = cifar10_batch[b'data']
print(f"Loaded test batch with {images.shape[0]} images")
# Out:
# Loaded test batch with 10000 images

# %% [markdown]
# # New Section

# %%
# Create a dataset from the images array
class TestDatasetFromArray(Dataset):
    def __init__(self, images, transform=None):
        self.images = images
        if transform is None:
            # Default transform: convert numpy array to PIL Image, then to tensor, then normalize
            self.transform = transforms.Compose([
                transforms.ToPILImage(),
                transforms.ToTensor(),
                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
            ])
        else:
            self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img = self.images[idx]
        if isinstance(img, np.ndarray):
            img = img.astype('uint8')
        if self.transform:
            img = self.transform(img)
        return img

# Create the test dataset and dataloader
test_dataset = TestDatasetFromArray(images)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)

# %%
# Inference Mode
# This cell loads a saved model checkpoint (if available) and runs inference on the test dataset.
# Predictions are then saved to a CSV file.

if os.path.exists("model_checkpoint.pth"):
    model.load_state_dict(torch.load("model_checkpoint.pth", map_location=device))
    print("Loaded model checkpoint from model_checkpoint.pth")
else:
    print("No checkpoint found. Running inference with untrained model.")

model.eval()
predictions = []
with torch.no_grad():
    for batch in test_loader:
        batch = batch.to(device)
        outputs = model(batch)
        _, preds = torch.max(outputs, 1)
        predictions.extend(preds.cpu().numpy().tolist())

# Save predictions to CSV using pandas
df = pd.DataFrame({"Id": range(len(predictions)), "Prediction": predictions})
df.to_csv("cifar_test_predictions.csv", index=False)
print("Predictions saved to cifar_test_predictions.csv")
# Out:
# <ipython-input-15-96cc9c5cad11>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("model_checkpoint.pth", map_location=device))
# Loaded model checkpoint from model_checkpoint.pth
# Predictions saved to cifar_test_predictions.csv

# %% [markdown]
# ## Instructions
#
# 1. **Training Section:** Run the training cell to train the model on CIFAR-10. The model checkpoint will be saved as `model_checkpoint.pth`.
# 2. **Inference Section:** Ensure the test pickle file is available at `/kaggle/input/deep-learning-spring-2025-project-1/cifar_test_nolabel.pkl`. Then run the inference cell to generate predictions, which will be saved to `cifar_test_predictions.csv`.
#
# Feel free to adjust hyperparameters (like epochs) as needed.
